# %%
# AVERAGE POPULATION COVERED BY A SINGLE SUB CENTRE, PHC, CHC

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#path of file to be opened
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\pop_covered_statewise\HP_pop.csv")

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')
pos = list(range(len(data['sub-centre']))) # setting position of the graphs
width = 0.25
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data['sub-centre'],width , alpha=0.5 , color='#EE3224',label=data['year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['phc'],width,alpha = 0.5,color='#FFC222',label=data['year'][1])
autolabel(rect2)
rect3 = plt.bar([p+width*2 for p in pos],data['chc'],width,alpha=0.5,color='#F78F1E',label=data['year'][2])
autolabel(rect3)
ax.set_xlabel('Year')
ax.set_ylabel('Average population covered')
ax.set_title('Average rural population covered in Himachal Pradesh across years(2005-14)')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['year'])
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(data['sub-centre'] + data['phc'] + data['chc'])] )
plt.legend(['sub-centre', 'phc', 'chc'], loc='center')
plt.grid()
plt.show()

# %%
# BUILDING POSITION OF SUB CENTRES
# starting at year:2005-2014

import plotly
plotly.tools.set_credentials_file(username='nirmit', api_key='0q6xb4al8m') #enter your plotly credentials
import xlrd
import plotly.plotly as py
import plotly.graph_objs as go
file_location = "C:/Users/Nirmit/kanoe_project/building_pos_sc/HP_build.xlsx" #enter path here
workbook = xlrd.open_workbook(file_location)
sheet = workbook.sheet_by_index(0)
labels=[]
values = []
labels.append(sheet.cell_value(0,1))
labels.append(sheet.cell_value(0,2))
labels.append(sheet.cell_value(0,3))
row = 1 #1 corresponds to starting year
for col in range(1,4) :
    ele = sheet.cell_value(row,col)
    values.append(ele)
fig = {
   'data': [{'labels': labels,
             'values': values,
             'type': 'pie'}],
    'layout': {'title': 'Himachal Pradesh SubCenter Status'}
     }
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nirmit/30.embed" height="525px" width="100%"></iframe>

# %%
# BUILDING POSITION OF PRIMARY HEALTH CENTRES
# starting at year:2005-2012

import plotly
plotly.tools.set_credentials_file(username='nirmit', api_key='0q6xb4al8m') #enter your plotly credentials
import xlrd
import plotly.plotly as py
import plotly.graph_objs as go
file_location ="C:/Users/Nirmit/kanoe_project/building_pos_phc/HP_pbuild.xlsx" #enter path here
workbook = xlrd.open_workbook(file_location)
sheet = workbook.sheet_by_index(0)
labels=[]
values = []
labels.append(sheet.cell_value(0,1))
labels.append(sheet.cell_value(0,2))
labels.append(sheet.cell_value(0,3))
row = 1 #1 corresponds to starting year
for col in range(1,4) :
    ele = sheet.cell_value(row,col)
    values.append(ele)
fig = {
   'data': [{'labels': labels,
             'values': values,
             'type': 'pie'}],
    'layout': {'title': 'Himachal Pradesh PHC Status'}
     }
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nirmit/92.embed" height="525px" width="100%"></iframe>

# %%
# BUIDLING POSITION OF COMMUNITY HEALTH CENTRES
# starting at year:2006;2007;2009;2010

import plotly
plotly.tools.set_credentials_file(username='nirmit', api_key='0q6xb4al8m') #enter your plotly credentials
import xlrd
import plotly.plotly as py
import plotly.graph_objs as go
file_location ="C:/Users/Nirmit/kanoe_project/building_pos_chc/HP_chcpos.xlsx" #enter path here
workbook = xlrd.open_workbook(file_location)
sheet = workbook.sheet_by_index(0)
labels=[]
values = []
labels.append(sheet.cell_value(0,1))
labels.append(sheet.cell_value(0,2))
labels.append(sheet.cell_value(0,3))
row = 1 #1 corresponds to starting year
for col in range(1,4) :
    ele = sheet.cell_value(row,col)
    values.append(ele)
fig = {
   'data': [{'labels': labels,
             'values': values,
             'type': 'pie'}],
    'layout': {'title': 'Himachal Pradesh CHC Status'}
     }
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nirmit/152.embed" height="525px" width="100%"></iframe>

# %%
# DEATH RATE VS YEAR

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\death_statewise\HP_death.csv")#enter path here
year=data['Year']
death = data['death_rate']
rect = plt.bar(year,death,align='center')
plt.xlabel('Year')
plt.ylabel('Death Rate')
plt.title('Death Rate in HP across years')
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')
bar_width=0.35
plt.xticks(np.arange(min(year), max(year)+1, 1.0),('2005','2006','2007','2008','2009','2010','2011','2012','2013'),rotation='vertical')
autolabel(rect)
plt.grid(True)
plt.ylim([0,9])
plt.show()

# %%
# DEATH RATE VS SHORTFALL IN DOCTORS AT PHCs
# negative shortfall indicates surplus

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\death_statewise\HP_death.csv")#enter path here
death_rate = data['death_rate']
Shortfall = data['Shortfall']
plt.scatter(death_rate,Shortfall)
plt.xlabel('DeathRate')
plt.ylabel('Shortfall(R-P)')
plt.title('DeathRate VS Shortfall(2005-13)')
plt.grid(True)
plt.show()

# %%
# REQUIRED-SANCTION-IN POSITION OF DOCTORS IN PHC

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\doctors_phc\HP_rsp_phc.csv")#enter path here
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')		
pos = list(range(len(data['R']))) # setting position of the graphs
width = 0.25
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data['R'],width , alpha=0.5 , color='#EE3224',label=data['year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['S'],width,alpha = 0.5,color='#FFC222',label=data['year'][1])
autolabel(rect2)
rect3 = plt.bar([p+width*2 for p in pos],data['P'],width,alpha=0.5,color='#F78F1E',label=data['year'][2])
autolabel(rect3)
ax.set_xlabel('Year')
ax.set_ylabel('No of doctors')
ax.set_title('Number of doctors in PHC in HP across years 2005-14')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['year'])
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, 800] )
plt.legend(['Required', 'Sanctioned', 'InPosition'], loc='upper left')
plt.grid()
plt.show()

# %%
# INFANT MORTALITY RATE VS YEAR

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\imr_statewise\HP_imr.csv")#enter path here
year=data['Year']
death = data['IMR-rural']
rect = plt.bar(year,death,align='center')
plt.xlabel('Year')
plt.ylabel('No of infant deaths')
plt.title('IMR in Himachal Pradesh across years')
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')
bar_width=0.35
plt.xticks(np.arange(min(year), max(year)+1, 1.0),('2004','2005','2006','2007','2008','2009','2010','2011','2012','2013'),rotation='vertical')
autolabel(rect)
plt.ylim([0, 90] )
plt.grid(True)
plt.show()

# %%
# FACILITIES AT CHC

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\chcf\HP_fchc.csv")#enter path here
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')			
pos = list(range(len(data['With functioning Stabilization Units for New Born']))) # setting position of the graphs
width = 0.2
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data['With functioning Stabilization Units for New Born'],width , alpha=0.5 , color='#ff99cc',label=data['year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['With New Born Care Corner'],width,alpha = 0.5,color='#d5beff',label=data['year'][1])
autolabel(rect2)
ax.set_xlabel('Year')
ax.set_ylabel('Percentage')
ax.set_title('CHC facilities in Himachal Pradesh across years')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['year'])
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, 100] )
plt.legend(['With functioning Stabilization Units for New Born', 'With New Born Care Corner'], loc='upper left')
plt.grid()
plt.show()

# %%
# REQUIRED-SANCTION-IN POSITION OF PEDIATRICIANS IN CHC

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\pediatricians_statewise\HP_pedia.csv")#enter path here
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')			
pos = list(range(len(data['Paediatricians - Required1 - [R]']))) # setting position of the graphs
width = 0.25
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data['Paediatricians - Required1 - [R]'],width , alpha=0.5 , color='#EE3224',label=data['Year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['Paediatricians - Sanctioned - [S]'],width,alpha = 0.5,color='#FFC222',label=data['Year'][1])
autolabel(rect2)
rect3 = plt.bar([p+width*2 for p in pos],data['Paediatricians - In Position - [P]'],width,alpha=0.5,color='#F78F1E',label=data['Year'][2])
autolabel(rect3)
ax.set_xlabel('Year')
ax.set_ylabel('No of pediatricians')
ax.set_title('Number of pediatricians in Himachal Pradesh across years')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['Year'])
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, 150] )
plt.legend(['Required', 'Sanctioned', 'InPosition'], loc='upper left')
plt.grid()
plt.show()

# %%
# FACILITIES AT PHC

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\phcf\HP_fphc.csv")#enter path here
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')			
pos = list(range(len(data['With Labour Room']))) # setting position of the graphs
width = 0.2
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data['With Labour Room'],width , alpha=0.5 , color='#ff99cc',label=data['year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['With Operation Theatre'],width,alpha = 0.5,color='#d5beff',label=data['year'][1])
autolabel(rect2)
rect3 = plt.bar([p+width*2 for p in pos],data['With 4-6 Beds'],width,alpha=0.5,color='#9988cc',label=data['year'][2])
autolabel(rect3)
rect4 = plt.bar([p+width*3 for p in pos],data['With 24 Hrs. Delivery Facility'],width,alpha=0.5,color='#00aadd',label=data['year'][3])
autolabel(rect4)
ax.set_xlabel('Year')
ax.set_ylabel('Percentage')
ax.set_title('PHC facilities in Himachal Pradesh across years')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['year'])
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, 100] )
plt.legend(['With Labour Room', 'With Operation Theatre', 'With 4-6 Beds','With 24 Hrs. Delivery Facility'], loc='upper center')
plt.grid()
plt.show()

# %%
# REQUIRED, SANCTIONED, IN-POSITION OF OBSTETRICIANS AND GYNAECOLOGISTS AT CHC

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\o&g_statewise\HP_og.csv")#enter path here
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')			
pos = list(range(len(data['R']))) # setting position of the graphs
width = 0.25
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data['R'],width , alpha=0.5 , color='#EE3224',label=data['Year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['P'],width,alpha = 0.5,color='#FFC222',label=data['Year'][1])
autolabel(rect2)
#rect3 = plt.bar([p+width*2 for p in pos],data['P'],width,alpha=0.5,color='#F78F1E',label=data['Year'][2])
#autolabel(rect3)
ax.set_xlabel('Year')
ax.set_ylabel('No of obstetricians & gynaecologists')
ax.set_title('Obstetricians & Gynaecologists in Himachal Pradesh across years')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['Year'])
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, 110] )
plt.legend(['Required',  'InPosition'], loc='upper left')
plt.grid()
plt.show()

# %%
# FACILITIES AT SUB CENTRES

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\sc_facilities_statewise\HP_fsc.csv")#enter path here
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')			
pos = list(range(len(data['Without Regular Water Supply']))) # setting position of the graphs
width = 0.2
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data['Without Regular Water Supply'],width , alpha=0.5 , color='#ff99cc',label=data['year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['Without Electric Supply'],width,alpha = 0.5,color='#d5beff',label=data['year'][1])
autolabel(rect2)
rect3 = plt.bar([p+width*2 for p in pos],data['Without All-Weather Motorable  Approach Road'],width,alpha=0.5,color='#9988cc',label=data['year'][2])
autolabel(rect3)
ax.set_xlabel('Year')
ax.set_ylabel('Percentage')
ax.set_title('Sub Centre facilities in Himachal Pradesh across years')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['year'])
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, 100] )
plt.legend(['Without Regular Water Supply', 'Without Electric Supply', 'Without All-Weather Motorable Approach Road'], loc='upper left')
plt.grid()
plt.show()

# %%
# OTHER FACILITIES AT PHC

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\phcf\HP_fphc.csv")#enter path here
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')			
pos = list(range(len(data[' Without Electric Supply']))) # setting position of the graphs
width = 0.15
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data[' Without Electric Supply'],width , alpha=0.7 , color='#0e2f44',label=data['year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['Without Regular Water Supply'],width,alpha = 0.5,color='#ff7f50',label=data['year'][1])
autolabel(rect2)
rect3 = plt.bar([p+width*2 for p in pos],data['Without AllWeather Motorable Approach Road'],width,alpha=0.5,color='#6897bb',label=data['year'][2])
autolabel(rect3)
rect4 = plt.bar([p+width*3 for p in pos],data['With Telephone'],width,alpha=0.5,color='#66cdaa',label=data['year'][3])
autolabel(rect4)
rect5 = plt.bar([p+width*4 for p in pos],data['With Computer'],width,alpha=0.5,color='#8b0000',label=data['year'][4])
autolabel(rect5)
ax.set_xlabel('Year')
ax.set_ylabel('Percentage')
ax.set_title('PHC facilities in Himachal Pradesh across years')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['year'])
plt.xlim(min(pos)-width, max(pos)+width*6)
plt.ylim([0, 100] )
plt.legend([' Without Electric Supply', 'Without Regular Water Supply', 'Without AllWeather Motorable Approach Road','With Telephone','With Computer'], loc='center')
plt.grid()
plt.show()

# %%
# OTHER FACILITIES AT CHC

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\chcf\HP_fchc.csv")#enter path here
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 0.95*height, '%d'%int(height),
                ha='center', va='bottom')			
pos = list(range(len(data['With all four specialists']))) # setting position of the graphs
width = 0.2
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data['With all four specialists'],width , alpha=0.5 , color='#ffd700',label=data['year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['With functional O.T.'],width,alpha = 0.5,color='#469649',label=data['year'][1])
autolabel(rect2)
rect3 = plt.bar([p+width*2 for p in pos],data['With functional Labor Room'],width,alpha = 0.5,color='#b4eeb4',label=data['year'][2])
autolabel(rect3)
rect4 = plt.bar([p+width*3 for p in pos],data['With at least 30 beds'],width,alpha = 0.5,color='#bf1616',label=data['year'][3])
autolabel(rect4)
ax.set_xlabel('Year')
ax.set_ylabel('Percentage')
ax.set_title('Other CHC facilities in Himachal Pradesh across years')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['year'])
plt.xlim(min(pos)-width, max(pos)+width*6)
plt.ylim([0, 100] )
plt.legend(['With all four specialists', 'With functional O.T.','With functional Labor Room','With at least 30 beds'], loc='center')
plt.grid()
plt.show()

# %%
# REQUIRED, SACNTIONED, IN-POSITION OF DOCTORS AT CHCs

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("C:\Users\Nirmit\kanoe_project\doctors_chc\HP_chc.csv")#enter path here
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')				
pos = list(range(len(data['R']))) # setting position of the graphs
width = 0.25
fig, ax = plt.subplots(figsize=(10,5)) # plotting the graphs
rect1=plt.bar(pos,data['R'],width , alpha=0.5 , color='#EE3224',label=data['Year'][0])
autolabel(rect1)
rect2 = plt.bar([p+width for p in pos],data['S'],width,alpha = 0.5,color='#FFC222',label=data['Year'][1])
autolabel(rect2)
rect3 = plt.bar([p+width*2 for p in pos],data['P'],width,alpha=0.5,color='#F78F1E',label=data['Year'][2])
autolabel(rect3)
ax.set_xlabel('Year')
ax.set_ylabel('No of doctors')
ax.set_title('RSP of doctors at CHCs in Himachal Pradesh across years')
ax.set_xticks([p + 1.5 * width for p in pos])
ax.set_xticklabels(data['Year'])
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, 600] )
plt.legend(['Required', 'Sanctioned', 'InPosition'], loc='upper left')
plt.grid()
plt.show()
